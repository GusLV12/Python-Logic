# %% [markdown]
# ## Correlation
# * **Tukey Intermediate**
#
# > Oct 28°, 2024

# %% [markdown]
# * First we need to **import** all the **libraries** we are going to use

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# * Check our data

# %%
chocolate = pd.read_csv('chocolate.csv')

chocolate.head()
# Out:
#     ref company_manufacturer company_location  review_date  \
# 0  2454                 5150           U.S.A.         2019
# 1  2458                 5150           U.S.A.         2019
# 2  2454                 5150           U.S.A.         2019
# 3  2542                 5150           U.S.A.         2021
# 4  2546                 5150           U.S.A.         2021
#
#   country_of_bean_origin specific_bean_origin_or_bar_name cocoa_percent  \
# 0               Tanzania            Kokoa Kamili, batch 1           76%
# 1     Dominican Republic                  Zorzal, batch 1           76%
# 2             Madagascar           Bejofo Estate, batch 1           76%
# 3                   Fiji            Matasawalevu, batch 1           68%
# 4              Venezuela            Sur del Lago, batch 1           72%
#
#   ingredients     most_memorable_characteristics  rating
# 0    3- B,S,C          rich cocoa, fatty, bready    3.25
# 1    3- B,S,C             cocoa, vegetal, savory    3.50
# ...

# %%
chocolate.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2530 entries, 0 to 2529
# Data columns (total 10 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   ref                               2530 non-null   int64
#  1   company_manufacturer              2530 non-null   object
#  2   company_location                  2530 non-null   object
#  3   review_date                       2530 non-null   int64
#  4   country_of_bean_origin            2530 non-null   object
#  5   specific_bean_origin_or_bar_name  2530 non-null   object
#  6   cocoa_percent                     2530 non-null   object
#  7   ingredients                       2443 non-null   object
#  8   most_memorable_characteristics    2530 non-null   object
#  9   rating                            2530 non-null   float64
# dtypes: float64(1), int64(2), object(7)
# memory usage: 197.8+ KB

# %% [markdown]
# * Set datatype of 'Cocoa Percent' to float

# %%
# Change data typw of 'cocoa_percent' to float
chocolate['cocoa_percent'] = chocolate['cocoa_percent'].str.replace('%', '').astype(float)

chocolate.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2530 entries, 0 to 2529
# Data columns (total 10 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   ref                               2530 non-null   int64
#  1   company_manufacturer              2530 non-null   object
#  2   company_location                  2530 non-null   object
#  3   review_date                       2530 non-null   int64
#  4   country_of_bean_origin            2530 non-null   object
#  5   specific_bean_origin_or_bar_name  2530 non-null   object
#  6   cocoa_percent                     2530 non-null   float64
#  7   ingredients                       2443 non-null   object
#  8   most_memorable_characteristics    2530 non-null   object
#  9   rating                            2530 non-null   float64
# dtypes: float64(2), int64(2), object(6)
# memory usage: 197.8+ KB

# %%
x_values = chocolate['cocoa_percent']
y_values = chocolate['rating']

plt.scatter(x_values, y_values)
plt.xlabel('Cocoa %')
plt.ylabel('Rating')
plt.title('Cocoa % vs. Rating')
plt.show()

# %% [markdown]
# * Check visual relationships between numeric dimensions

# %%
# # Get all the numeric columns
# numeric_columns = chocolate.select_dtypes(include=[np.number]).columns

sns.pairplot(chocolate, diag_kind='kde')
plt.show()

# %% [markdown]
# * How to perform a correlation matrix

# %%
# # Get all the numeric columns
numeric_columns = chocolate.select_dtypes(include=[np.number]).columns

# Get the correlation matrix
correlation_matrix = chocolate[numeric_columns].corr()

print(correlation_matrix)
# Out:
#                     ref  review_date  cocoa_percent    rating
# ref            1.000000     0.993126       0.015835  0.113398
# review_date    0.993126     1.000000       0.016484  0.116256
# cocoa_percent  0.015835     0.016484       1.000000 -0.146690
# rating         0.113398     0.116256      -0.146690  1.000000

# %% [markdown]
# * How to do a heatmap

# %%
sns.heatmap(correlation_matrix, annot=True, cmap='viridis')
# Out:
# <Axes: >

# %% [markdown]
# # Repaso (creo)

# %% [markdown]
# ### Media
# La media es el promedio de un conjunto de datos y representa el valor central de una distribución. Se calcula sumando todos los valores y dividiéndolos por el número total de elementos.
#
# **Fórmula**:
# $$
# \text{Media} = \frac{1}{N} \sum_{i=1}^{N} X_i
# $$
# donde \( N \) es el número de datos y \( X_i \) representa cada valor.
#
# ### Dispersión
# La dispersión mide cuánto varían los datos respecto a la media, indicando la extensión o variabilidad de los valores. Algunas medidas comunes son la varianza y el rango intercuartílico.
#
# (No tiene una fórmula específica, ya que es un concepto general que agrupa varias medidas).
#
# ### Varianza
# La varianza es el promedio de los cuadrados de las desviaciones respecto a la media. Cuanto mayor es la varianza, mayor es la dispersión de los datos.
#
# **Fórmula**:
# $$
# \text{Varianza} = \frac{1}{N} \sum_{i=1}^{N} (X_i - \text{Media})^2
# $$
#
# ### Desviación Estándar
# La desviación estándar es la raíz cuadrada de la varianza y mide cuánto se alejan en promedio los datos respecto a la media. Es útil para entender la dispersión en unidades originales de los datos.
#
# **Fórmula**:
# $$
# \text{Desviación Estándar} = \sqrt{\frac{1}{N} \sum_{i=1}^{N} (X_i - \text{Media})^2}
# $$

# %% [markdown]
# ## Evento de Probabilidad
# Un evento de probabilidad es un conjunto de posibles resultados de un experimento aleatorio. Especifica las circunstancias bajo las cuales ocurren ciertos resultados, como obtener "cara" al lanzar una moneda. Los eventos se representan con variables aleatorias, que asignan valores numéricos a los posibles resultados de un experimento.
#
# ## Variables Aleatorias
# Una variable aleatoria es una función que asigna un valor numérico a cada resultado de un experimento. Las variables aleatorias permiten modelar y cuantificar la ocurrencia de eventos, facilitando el cálculo de probabilidades en distintos escenarios.
#
# ## Ensayo de Bernoulli
# Un ensayo de Bernoulli es un experimento aleatorio con solo dos resultados posibles: éxito o fracaso (generalmente representados como 1 y 0, respectivamente). Cada ensayo tiene una probabilidad fija de éxito \( p \), y los resultados son independientes de otros ensayos. Este tipo de ensayo es la base de la distribución binomial.

# %% [markdown]
# # Distributions

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Assuming you have a DataFrame 'df'
# Select only the numeric columns
numeric_cols = chocolate.select_dtypes(include='number').columns

# Plot the distribution of each numeric column
for col in numeric_cols:
    plt.figure(figsize=(8, 4))
    sns.histplot(chocolate[col], kde=True)  
    plt.title(f'Distribution of {col}')
    plt.xlabel(col)
    plt.ylabel('Frequency')
    plt.show()

# %% [markdown]
# ## Ploto by exact values

# %%
for col in numeric_cols:
    plt.figure(figsize=(8, 4))
    sns.countplot(x=chocolate[col]) 
    plt.title(f'Distribution of {col}')
    plt.xlabel(col)
    plt.ylabel('Count')
    plt.xticks(rotation=45)  # Rotate x-axis labels if needed
    plt.show()

# %%
# Selecting non-numeric columns
non_numeric_cols = chocolate.select_dtypes(exclude=['number']).columns

# Plotting distribution of each non-numeric column
for col in non_numeric_cols:
    plt.figure(figsize=(8, 4))
    sns.countplot(x=chocolate[col])
    plt.title(f'Distribution of {col}')
    plt.xlabel(col)
    plt.ylabel('Count')
    plt.xticks(rotation=45)  # Rotate x-axis labels for better readability
    plt.show()

# %%
for col in non_numeric_cols:
    plt.figure(figsize=(8, 4))
    
    # Get the top 10 most frequent values
    top_values = chocolate[col].value_counts().nlargest(10).index
    top_data = chocolate[chocolate[col].isin(top_values)]
    
    # Plot
    sns.countplot(x=top_data[col], order=top_values)
    plt.title(f'Top 10 Most Repeated Values in {col}')
    plt.xlabel(col)
    plt.ylabel('Count')
    plt.xticks(rotation=45)  # Rotate x-axis labels for better readability
    plt.show()

# %%
for col in non_numeric_cols:
    plt.figure(figsize=(8, 4))
    
    # Get the top 10 most frequent values
    top_values = chocolate[col].value_counts().nsmallest(10).index
    top_data = chocolate[chocolate[col].isin(top_values)]
    
    # Plot
    sns.countplot(x=top_data[col], order=top_values)
    plt.title(f'Top 10 Less Repeated Values in {col}')
    plt.xlabel(col)
    plt.ylabel('Count')
    plt.xticks(rotation=45)  # Rotate x-axis labels for better readability
    plt.show()

# %% [markdown]
# # Distribuciones de probabilidad

# %% [markdown]
# | **Distribución**                 | **Descripción**                                                                 | **Propiedades Matemáticas**                                                                                                    | **Aplicaciones en ML**                                                                                      |
# |----------------------------------|---------------------------------------------------------------------------------|-------------------------------------------------------------------------------------------------------------------------------|---------------------------------------------------------------------------------------------------------------|
# | **Distribución Normal** (Gaussiana)  | Distribución continua caracterizada por una curva en forma de campana, simétrica alrededor de la media.               | - Definida por la media (μ) y la desviación estándar (σ).<br>- El 68% de los datos cae dentro de 1σ, el 95% dentro de 2σ, y el 99.7% dentro de 3σ. | - Escalado de características (normalización, estandarización).<br>- Clasificador de Naive Bayes Gaussiano.<br>- Pruebas de suposición (por ejemplo, pruebas t). |
# | **Distribución Binomial**             | Distribución discreta que representa el número de éxitos en un número fijo de ensayos independientes.    | - Definida por el número de ensayos (n) y la probabilidad de éxito (p).<br>- Función de masa de probabilidad: <br> \(P(X = k) = \binom{n}{k} p^k (1-p)^{n-k}\) | - Clasificación binaria (por ejemplo, regresión logística).<br>- Pruebas A/B para comparar versiones.<br>- Evaluación de métricas de modelos (precisión, recall). |
# | **Distribución de Poisson**           | Distribución discreta para el número de eventos en un intervalo fijo, dado un promedio conocido (λ).    | - Definida por la tasa promedio (λ).<br>- Función de masa de probabilidad: <br> \(P(X = k) = \frac{\lambda^k e^{-\lambda}}{k!}\) | - Modelado de datos de conteo (por ejemplo, clics, ventas).<br>- Detección de anomalías basada en conteos de eventos.<br>- Regresión de Poisson para predicción de conteos. |

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from scipy.stats import norm

# Parameters for the Normal Distribution
mu, sigma = 0, 1  # Mean and standard deviation

# Generate data
data = np.random.normal(mu, sigma, 1000)

# Create a figure with subplots
fig, axes = plt.subplots(1, 3, figsize=(18, 5))

# 1. Probability Density Function (PDF)
sns.histplot(data, bins=30, kde=True, stat='density', ax=axes[0])
axes[0].set_title('Normal Distribution - PDF')
axes[0].set_xlabel('Value')
axes[0].set_ylabel('Density')

# 2. Cumulative Distribution Function (CDF)
sns.ecdfplot(data, ax=axes[1])
axes[1].set_title('Normal Distribution - CDF')
axes[1].set_xlabel('Value')
axes[1].set_ylabel('Cumulative Probability')

# 3. Histogram with fitted distribution
sns.histplot(data, bins=30, stat='density', ax=axes[2])
x = np.linspace(mu - 4*sigma, mu + 4*sigma, 100)
axes[2].plot(x, norm.pdf(x, mu, sigma), color='red', lw=2)
axes[2].set_title('Normal Distribution - Histogram with Fitted PDF')
axes[2].set_xlabel('Value')
axes[2].set_ylabel('Density')

plt.tight_layout()
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from scipy.stats import binom

# Parameters for the Binomial Distribution
n, p = 10, 0.5  # Number of trials and probability of success

# Generate data
data = binom.rvs(n, p, size=1000)

# Create a figure with subplots
fig, axes = plt.subplots(1, 3, figsize=(18, 5))

# 1. Probability Mass Function (PMF)
x = np.arange(0, n+1)
axes[0].bar(x, binom.pmf(x, n, p), color='blue', alpha=0.7)
axes[0].set_title('Binomial Distribution - PMF')
axes[0].set_xlabel('Number of Successes')
axes[0].set_ylabel('Probability')

# 2. Cumulative Distribution Function (CDF)
axes[1].bar(x, binom.cdf(x, n, p), color='orange', alpha=0.7)
axes[1].set_title('Binomial Distribution - CDF')
axes[1].set_xlabel('Number of Successes')
axes[1].set_ylabel('Cumulative Probability')

# 3. Histogram with fitted PMF
sns.histplot(data, bins=n, stat='density', ax=axes[2], kde=False, color='lightgray')
axes[2].bar(x, binom.pmf(x, n, p), color='blue', alpha=0.7)
axes[2].set_title('Binomial Distribution - Histogram with Fitted PMF')
axes[2].set_xlabel('Number of Successes')
axes[2].set_ylabel('Density')

plt.tight_layout()
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from scipy.stats import poisson

# Parameters for the Poisson Distribution
lambda_ = 3  # Average rate of occurrence

# Generate data
data = poisson.rvs(lambda_, size=1000)

# Create a figure with subplots
fig, axes = plt.subplots(1, 3, figsize=(18, 5))

# 1. Probability Mass Function (PMF)
x = np.arange(0, 15)
axes[0].bar(x, poisson.pmf(x, lambda_), color='green', alpha=0.7)
axes[0].set_title('Poisson Distribution - PMF')
axes[0].set_xlabel('Number of Events')
axes[0].set_ylabel('Probability')

# 2. Cumulative Distribution Function (CDF)
axes[1].bar(x, poisson.cdf(x, lambda_), color='purple', alpha=0.7)
axes[1].set_title('Poisson Distribution - CDF')
axes[1].set_xlabel('Number of Events')
axes[1].set_ylabel('Cumulative Probability')

# 3. Histogram with fitted PMF
sns.histplot(data, bins=30, stat='density', ax=axes[2], kde=False, color='lightgray')
axes[2].bar(x, poisson.pmf(x, lambda_), color='green', alpha=0.7)
axes[2].set_title('Poisson Distribution - Histogram with Fitted PMF')
axes[2].set_xlabel('Number of Events')
axes[2].set_ylabel('Density')

plt.tight_layout()
plt.show()

# %% [markdown]
# | **Aspecto**                | **PMF**                                    | **CDF**                                       |
# |---------------------------|-------------------------------|------------|
# | **Tipo de Variable**      | Discreta                                   | Continua y discreta                          |
# | **Define**                | Probabilidad de un valor específico       | Probabilidad acumulativa hasta un valor     |
# | **Fórmula**               | \(P(X = x)\)                              | \(F(x) = P(X \leq x)\)                       |
# | **Suma/Integral**         | Suma sobre todos los valores posibles     | Integral o suma acumulativa de la PMF       |
# | **Interpretación**        | Probabilidad exacta                       | Probabilidad acumulativa hasta un valor      |

# %% [markdown]
# # Ejemplos:
#
# 1. Alturas de personas en una población específica.
# 2. Número de caras al lanzar una moneda varias veces.
# 3. Cantidad de llamadas que recibe un centro de atención telefónica por hora.
# 4. Errores de medición en experimentos científicos.
# 5. Cantidad de productos defectuosos en una muestra de producción.
# 6. Número de accidentes de tráfico en una intersección específica en un día.
# 7. Puntajes de exámenes estandarizados como el SAT o GRE.
# 8. Número de aprobados en una prueba para un grupo de estudiantes, asumiendo una probabilidad fija de aprobar.
# 9. Llegada de clientes a una tienda en un periodo determinado.

# %% [markdown]
# # Respuestas:
#
# 1.
# 2.
# 3.
# 4.
# 5.
# 6.
# 7.
# 8.
# 9.
